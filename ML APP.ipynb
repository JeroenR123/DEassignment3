# %%
import pandas as pd
df =  pd.read_csv("raw_data2.csv", error_bad_lines=False)
def dfreplace(df, *args, **kwargs):
    s = pd.Series(df.values.flatten())
    s = s.str.replace(*args, **kwargs)
    return pd.DataFrame(s.values.reshape(df.shape), df.index, df.columns)

df = dfreplace(df, ',', '')

# %%
df.head()
# Out:
#   Opmerking:      door stationsverplaatsingen                en  \
# 0          #      370:                  5.377            51.451
# 1          #  YYYYMMDD                      =             Datum
# 2          #     FHVEC                      =  Vectorgemiddelde
# 3          #       FHX                      =           Hoogste
# 4          #       FHN                      =           Laagste
#
#    veranderingen            in waarneemmethodieken   zijn   deze  \
# 0          22.60     EINDHOVEN                 NaN    NaN    NaN
# 1     (YYYY=jaar      MM=maand            DD=dag);    NaN    NaN
# 2   windsnelheid           (in                 0.1  m/s).    Zie
# 3  uurgemiddelde  windsnelheid                 (in    0.1  m/s);
# 4  uurgemiddelde  windsnelheid                 (in    0.1  m/s);
#
#                                          tijdreeksen  ... van.2   De Bilt  \
# 0                                                NaN  ...   NaN  NaN  NaN
# 1                                                NaN  ...   NaN  NaN  NaN
# 2  http://www.knmi.nl/kennis-en-datacentrum/achte...  ...   NaN  NaN  NaN
# 3                                                NaN  ...   NaN  NaN  NaN
# 4                                                NaN  ...   NaN  NaN  NaN
#
#   <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/gehomogeniseerde-reeks-maandtemperaturen-de-bilt>  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#     of de.1 Centraal Nederland Temperatuur  \
# 0  NaN  NaN      NaN       NaN         NaN
# 1  NaN  NaN      NaN       NaN         NaN
# 2  NaN  NaN      NaN       NaN         NaN
# 3  NaN  NaN      NaN       NaN         NaN
# 4  NaN  NaN      NaN       NaN         NaN
#
#   <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/centraal-nederland-temperatuur-cnt>.
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 48 columns]

# %%
import re
import numpy as np
for i in df.columns:
    df[i] = df[i].astype(str)
    df[i][df[i].apply(lambda i: True if re.search('^\s*$', str(i)) else False)]=np.NaN

# %%
df['YYYY'] = df['YYYYMMDD,'].str.slice(0,4) #create a variable for years
df['MM'] = df['YYYYMMDD,'].str.slice(4,6)#create a variable for months
df['DD'] = df['YYYYMMDD,'].str.slice(6,8)
for i in df.columns:
        df[i] =df[i].astype(int, errors= 'ignore') 
df = df.drop('YYYYMMDD,', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YYYYMMDD,'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-d4518f7f8a1b> in <module>
# ----> 1 df['YYYY'] = df['YYYYMMDD,'].str.slice(0,4) #create a variable for years
#       2 df['MM'] = df['YYYYMMDD,'].str.slice(4,6)#create a variable for months
#       3 df['DD'] = df['YYYYMMDD,'].str.slice(6,8)
#       4 for i in df.columns:
#       5         df[i] =df[i].astype(int, errors= 'ignore')
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'YYYYMMDD,'

# %%
#df['YYYY'] = df['YYYYMMDD,'].dt.year #create a variable for years
#df['MM'] = df['YYYYMMDD,'].dt.month #create a variable for months
#df['DD'] = df['YYYYMMDD,'].dt.day #create a variable for days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7329 entries, 0 to 7328
# Data columns (total 48 columns):
#  #   Column                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                   --------------  -----
#  0   Opmerking:                                                                                               7329 non-null   object
#  1   door                                                                                                     7329 non-null   object
#  2   stationsverplaatsingen                                                                                   7328 non-null   object
#  3   en                                                                                                       7328 non-null   object
#  4   veranderingen                                                                                            7328 non-null   object
#  5   in                                                                                                       7328 non-null   object
#  6   waarneemmethodieken                                                                                      7328 non-null   object
#  7   zijn                                                                                                     7328 non-null   object
#  8   deze                                                                                                     7328 non-null   object
#  9   tijdreeksen                                                                                              7329 non-null   object
#  10  van                                                                                                      7329 non-null   object
#  11  dagwaarden                                                                                               7329 non-null   object
#  12  mogelijk                                                                                                 7329 non-null   object
#  13  inhomogeen!                                                                                              7329 non-null   object
#  14  Dat                                                                                                      7329 non-null   object
#  15  betekent                                                                                                 7329 non-null   object
#  16  dat                                                                                                      7329 non-null   object
#  17  deze.1                                                                                                   7329 non-null   object
#  18  reeks                                                                                                    7329 non-null   object
#  19  van.1                                                                                                    7329 non-null   object
#  20  gemeten                                                                                                  7329 non-null   object
#  21  waarden                                                                                                  7329 non-null   object
#  22  niet                                                                                                     7329 non-null   object
#  23  geschikt                                                                                                 7329 non-null   object
#  24  is                                                                                                       7329 non-null   object
#  25  voor                                                                                                     7329 non-null   object
#  26  trendanalyse.                                                                                            7329 non-null   object
#  27  Voor                                                                                                     7329 non-null   object
#  28  studies                                                                                                  7329 non-null   object
#  29  naar                                                                                                     7329 non-null   object
#  30  klimaatverandering                                                                                       7312 non-null   object
#  31  verwijzen                                                                                                7312 non-null   object
#  32  we                                                                                                       7312 non-null   object
#  33  naar.1                                                                                                   7312 non-null   object
#  34  de                                                                                                       5510 non-null   object
#  35  gehomogeniseerde                                                                                         7329 non-null   object
#  36  reeks.1                                                                                                  7329 non-null   object
#  37  maandtemperaturen                                                                                        7329 non-null   object
#  38  van.2                                                                                                    7329 non-null   object
#  39  De                                                                                                       7329 non-null   object
#  40  Bilt                                                                                                     7329 non-null   object
#  41  <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/gehomogeniseerde-reeks-maandtemperaturen-de-bilt>  7329 non-null   object
#  42  of                                                                                                       7329 non-null   object
#  43  de.1                                                                                                     7329 non-null   object
#  44  Centraal                                                                                                 7329 non-null   object
#  45  Nederland                                                                                                7329 non-null   object
#  46  Temperatuur                                                                                              7329 non-null   object
#  47  <http://www.knmi.nl/kennis-en-datacentrum/achtergrond/centraal-nederland-temperatuur-cnt>.               7329 non-null   object
# dtypes: object(48)
# memory usage: 2.7+ MB

# %%
#counting = {}
#for value in df['STN,']:
#    counting[value] = counting.get(value, 0) + 1
#counting

# %%
#train and ev df
mask = df['YYYY']== 2019
test_df = df[mask]
ev_df  = df[~mask]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'YYYY'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-5971e8f0dc3e> in <module>
#       1 #train and ev df
# ----> 2 mask = df['YYYY']== 2019
#       3 test_df = df[mask]
#       4 ev_df  = df[~mask]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'YYYY'

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# get x and y
x_train, y_train = train_df.drop('TG,', axis=1), train_df['TG,']
# split the data for initial testing
X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size=0.2,random_state=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a5c0795657a1> in <module>
#       7
#       8 # get x and y
# ----> 9 x_train, y_train = train_df.drop('TG,', axis=1), train_df['TG,']
#      10 # split the data for initial testing
#      11 X_train, X_test, Y_train, Y_test = train_test_split(x_train, y_train, test_size=0.2,random_state=1)
#
# NameError: name 'train_df' is not defined

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)
